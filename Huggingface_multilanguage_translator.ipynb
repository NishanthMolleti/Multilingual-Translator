# %% [markdown]
# <a href="https://colab.research.google.com/github/NishanthMolleti/Multilingual-Translator/blob/main/Huggingface_multilanguage_translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! pip install transformers -U -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 13.8 MB/s eta 0:00:00

# %%
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# %%
pip install sentencepiece

# %%
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_1.2B")

# %%
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_1.2B")
# Out:
# tokenizer_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]

# %%
tokenizer.src_lang = "en"
src_text='because they got a shortage, I heard'
encoded_hi = tokenizer(src_text, return_tensors="pt")

# %%
generated_tokens = model.generate(**encoded_hi, forced_bos_token_id=tokenizer.get_lang_id("hi"))
tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
# Out:
# ['क्योंकि उन्हें एक कमी थी, मैंने सुना']
